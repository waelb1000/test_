# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.randint(100,size=(8, 2)))
plt.ylabel("temperature")
plt.xlabel("month")
# Out:
# Text(0.5, 0, 'month')

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25], 'ro')
plt.axis([-1,5, 0,20])
# Out:
# [-1, 5, 0, 20]
